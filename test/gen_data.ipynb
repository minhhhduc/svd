# %%
import os

# %%
path = '../data'
if os.path.exists(path):
    os.chdir(path)
os.getcwd()
# Out:
# 'e:\\subjects\\parallel_computing\\final_project\\data'

# %%
import numpy as np

matrix = np.random.rand(10, 10) * 1000
fileName = 'matrix.txt'

with open(fileName, 'w') as f:
    f.write(f'{matrix.shape[0]} {matrix.shape[1]}\n')
    np.savetxt(f, matrix, fmt='%.2f')
